# %% [markdown]
# In this notebook I´m going to check out the data I scraped via provided code I found on GitHub.

# %%
# import all needed libraries for this notebook
import pandas as pd

# %%
# load the tweets
data = pd.read_csv("trumptweets.csv", sep=';')

# %%
data.head(10)
# Out:
#           username            date  retweets  favorites  \
# 0  realDonaldTrump  09.02.20 00:47     13459      72445
# 1  realDonaldTrump  08.02.20 22:08     47880     215503
# 2  realDonaldTrump  08.02.20 20:48      9452      37402
# 3  realDonaldTrump  08.02.20 20:40     17545      62484
# 4  realDonaldTrump  08.02.20 20:01     27437     120598
# 5  realDonaldTrump  08.02.20 19:43     11595      51483
# 6  realDonaldTrump  08.02.20 19:43     12716      53876
# 7  realDonaldTrump  08.02.20 16:30     16359      64922
# 8  realDonaldTrump  08.02.20 16:16     26086     118446
# 9  realDonaldTrump  08.02.20 16:03     17840      74116
#
#                                                 text  geo mentions hashtags  \
# 0  A great coach and a fantastic guy. His endorse...  NaN      NaN      NaN
# 1  Pete Rose played Major League Baseball for 24 ...  NaN      NaN      NaN
# 2  Total and complete Endorsement for Debbie Lesk...  NaN   #NAME?      NaN
# ...

# %%
# check the data
print("Data frame shape: ", data.shape)
print("Type of date:", type(data.date))
print("Check text of tweet 10:")
print(data.date[9])
print(data.text[9])
# Out:
# Data frame shape:  (10250, 10)
# Type of date: <class 'pandas.core.series.Series'>
# Check text of tweet 10:
# 08.02.20 16:03
# Thank you Iowa for the RECORD vote we just received in the Primary. The Dems were 25% down (although their votes are all fried!). https:// twitter.com/realdonaldtrum p/status/1223077157779464195 …

# %%
from IPython.display import Image 
print("Check tweet printed above - 8th of February 2020")
Image("trumptweet-08.02.20.png")
# Out:
# Check tweet printed above - 8th of February 2020

# %% [markdown]
# 10.250 seems to be a **small number of tweets**, I expected something like 100.000 tweets.
# Have to **check this**, it´s could be the number of tweets he posted himself.
# His number of retweets is very big!
